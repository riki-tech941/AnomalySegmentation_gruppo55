# %%
# !git clone https://github.com/riki-tech941/AnomalySegmentation_gruppo55.git

# %% [markdown]
# The Cityscapes zip files need to be in the "eomt/cityscapes" folder <br>
# The anomaly segmentation dataset need to be unzipped in the "eomt/anomaly" folder <br>
# The .bin files of the pretrained models need to be in the "eomt/checkpoints/pretrained" folder <br>
# The .bin file of the finetuned model need to be in the "eomt/checkpoints/finetuned" folder <br>
# You can find the .bin file on the finetuned model at the link <br>
# https://drive.google.com/file/d/1aOojOlQrxVHXyUWjbAp8cp7-8KdFW-fM/view?usp=sharing

# %%
PATH_TO_CITYSCAPES_ZIP = '' # Add path to the cityscapes .zip files
PATH_TO_ANOMALY_SEGMENTATION_ZIP = '' # Add path to the anomaly segmentation .zip

# Add path to the .bin files with the weights of the pretrained modules and the finetuned module
PATH_TO_BIN_PRETRAINED_ON_CITYSCAPES = '' 
PATH_TO_BIN_PRETRAINED_ON_COCO = ''
PATH_TO_FINETUNED_MODEL = ''

# %%
# !mkdir -p ./AnomalySegmentation_gruppo55/eomt/cityscapes
# !mkdir -p ./AnomalySegmentation_gruppo55/eomt/anomaly
# !mkdir -p ./AnomalySegmentation_gruppo55/eomt/checkpoints/pretrained
# !mkdir -p ./AnomalySegmentation_gruppo55/eomt/checkpoints/finetuned

# !mv {PATH_TO_CITYSCAPES_ZIP}/*zip ./AnomalySegmentation_gruppo55/eomt/cityscapes
# !unzip -q {PATH_TO_ANOMALY_SEGMENTATION_ZIP} -d ./AnomalySegmentation_gruppo55/eomt/anomaly

# !mv {PATH_TO_BIN_PRETRAINED_ON_CITYSCAPES} ./AnomalySegmentation_gruppo55/eomt/checkpoints/pretrained/eomt_cityscapes.bin
# !mv {PATH_TO_BIN_PRETRAINED_ON_COCO} ./AnomalySegmentation_gruppo55/eomt/checkpoints/pretrained/eomt_coco.bin
# !mv {PATH_TO_FINETUNED_MODEL} ./AnomalySegmentation_gruppo55/eomt/checkpoints/finetuned/coco_finetuned_on_cityscapes.bin

# %% [markdown]
# Make sure you are in the ./eomt folder, otherwise the notebooks won't run properly

# %%
# %cd ./AnomalySegmentation_gruppo55/eomt

# %% [markdown]
# Install all the packets required by the project <br>
# The file ./requirements_colab.txt contains a snapshots of packages that should work on Colab

# %%
# %pip install -r ./requirements.txt

# %% [markdown]
# Evaluation of the models on semantic segmentation

# %%
# %run ./semantic_evaluation.ipynb

# %% [markdown]
# Evaluation of the mIoU of the ERFNEt model

# %%
# %run ./miou_erfnet.ipynb

# %% [markdown]
# Fine-tuning of the model trained on COCO on the Cityscapes dataset

# %%
# %run ./fine_tuning.ipynb

# %% [markdown]
# Anomaly segmentation evaluation of all the models <br>
# Sometimes Colab doesen't show the output of this notebook completely, because of the use of the subprocess module <br>
# If you don't see the AuPRC and FPR95 results, try to run the notebook directly

# %%
# %run ./anomaly_segmentation.ipynb
