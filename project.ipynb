# %%
# !git clone https://github.com/riki-tech941/AnomalySegmentation_gruppo55.git

# %% [markdown]
# The Cityscapes zip files need to be in the "eomt/cityscapes" folder <br>
# The anomaly segmentation dataset need to be unzipped in the "eomt/anomaly" folder <br>
# The .bin files of the pretrained models need to be in the "eomt/checkpoints/pretrained" folder <br>
# The .bin file of the finetuned model need to be in the "eomt/checkpoints/finetuned" folder <br>

# %%
PATH_TO_CITYSCAPES_ZIP = '' # Add path to the cityscapes .zip files
PATH_TO_ANOMALY_SEGMENTATION_ZIP = '' # Add path to the anomaly segmentation .zip

# Add path to the .bin files with the weights of the pretrained modules and the finetuned module
PATH_TO_BIN_PRETRAINED_ON_CITYSCAPES = '' 
PATH_TO_BIN_PRETRAINED_ON_COCO = ''
PATH_TO_FINETUNED_MODEL = ''

# %%
# !mkdir -p ./eomt/cityscapes
# !mkdir -p ./eomt/anomaly
# !mkdir -p ./eomt/checkpoints/pretrained
# !mkdir -p ./eomt/checkpoints/finetuned

# !mv {PATH_TO_CITYSCAPES_ZIP}/*zip ./eomt/cityscapes
# !unzip -q {PATH_TO_ANOMALY_SEGMENTATION_ZIP} -d ./eomt/anomaly

# !mv {PATH_TO_BIN_PRETRAINED_ON_CITYSCAPES} ./eomt/checkpoints/pretrained/eomt_cityscapes.bin
# !mv {PATH_TO_BIN_PRETRAINED_ON_COCO} ./eomt/checkpoints/pretrained/eomt_coco.bin
# !mv {PATH_TO_FINETUNED_MODEL} ./eomt/checkpoints/finetuned/coco_finetuned_on_cityscapes.bin

# %% [markdown]
# Install all the packets required by the project <br>
# The file ./eomt/requirements_cloab.txt contains a snapshot of a Colab environment where the notebooks were tested <br>

# %%
# %pip install -r ./eomt/requirements.txt

# %%
# %pip install -r ./eomt/requirements_colab.txt

# %% [markdown]
# Make sure you are in the ./eomt folder

# %%
# %cd eomt

# %% [markdown]
# Semantic evaluation notebook

# %%
# %run ./eomt/semantic_evaluation.ipynb

# %% [markdown]
# Anomaly segmentation notebook

# %%
# %run ./eomt/anomaly_segmentation.ipynb

# %% [markdown]
# Fine-tuning notebook

# %%
# %run ./eomt/fine_tuning.ipynb
