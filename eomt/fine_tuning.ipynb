# %% [markdown]
# Code to start fine-tuning

# %%
# !python main.py fit \
  -c ./configs/eomt_finetune_model_on_cityscapes.yaml \
  --trainer.devices 1 \
  --data.batch_size 2 \
  --data.num_workers 2 \
  --data.path ./cityscapes \
  --model.ckpt_path ./checkpoints/pretrained/eomt_coco.bin \
  --model.load_ckpt_class_head False
